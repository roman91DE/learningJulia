# %%
function Kₙ(K₀::Number, n:: Number, p:: Number)
    return K₀ * (1 + p)^n
end
# Out:
# Kₙ (generic function with 1 method)

# %%
function promptUser()
    println("Enter K₀:")
    K₀ = readline()
    #return typeof(K₀)
end

promptUser()
# Out:
# UndefVarError: execute_msg not defined
#
#
#
# Stacktrace:
#
#   [1] readprompt(prompt::String; password::Bool)
#
#     @ VSCodeServer.IJuliaCore c:\Users\Dozent\.vscode\extensions\julialang.language-julia-1.6.24\scripts\packages\IJuliaCore\src\stdio.jl:190
#
#   [2] readprompt
#
#     @ c:\Users\Dozent\.vscode\extensions\julialang.language-julia-1.6.24\scripts\packages\IJuliaCore\src\stdio.jl:190 [inlined]
#
#   [3] readline(io::VSCodeServer.IJuliaCore.IJuliaStdio{Base.PipeEndpoint, typeof(VSCodeServer.io_send_callback)})
#
#     @ VSCodeServer.IJuliaCore c:\Users\Dozent\.vscode\extensions\julialang.language-julia-1.6.24\scripts\packages\IJuliaCore\src\stdio.jl:232
#
#   [4] readline()
#
#     @ Base .\io.jl:509
#
#   [5] promptUser()
#
#     @ Main c:\Users\Dozent\learningJulia\tut1.ipynb:3
#
#   [6] top-level scope
#
#     @ c:\Users\Dozent\learningJulia\tut1.ipynb:7
#
#   [7] eval
#
#     @ .\boot.jl:373 [inlined]
#
# ...

# %%
# Out:
# UndefVarError: execute_msg not defined
#
#
#
# Stacktrace:
#
#   [1] readprompt(prompt::String; password::Bool)
#
#     @ VSCodeServer.IJuliaCore c:\Users\Dozent\.vscode\extensions\julialang.language-julia-1.6.24\scripts\packages\IJuliaCore\src\stdio.jl:190
#
#   [2] readprompt
#
#     @ c:\Users\Dozent\.vscode\extensions\julialang.language-julia-1.6.24\scripts\packages\IJuliaCore\src\stdio.jl:190 [inlined]
#
#   [3] readline(io::VSCodeServer.IJuliaCore.IJuliaStdio{Base.PipeEndpoint, typeof(VSCodeServer.io_send_callback)})
#
#     @ VSCodeServer.IJuliaCore c:\Users\Dozent\.vscode\extensions\julialang.language-julia-1.6.24\scripts\packages\IJuliaCore\src\stdio.jl:232
#
#   [4] readline()
#
#     @ Base .\io.jl:509
#
#   [5] promptUser()
#
#     @ Main c:\Users\Dozent\learningJulia\tut1.ipynb:3
#
#   [6] top-level scope
#
#     @ c:\Users\Dozent\learningJulia\tut1.ipynb:1
#
#   [7] eval
#
#     @ .\boot.jl:373 [inlined]
#
# ...
